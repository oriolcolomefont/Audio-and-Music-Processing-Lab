# %%
import json
import os
from collections import defaultdict

import numpy as np
import matplotlib.pyplot as plt

from music21 import *
from tqdm import tqdm
import pandas as pd
# Out:
# /var/folders/xh/n0x8mh015rj1js80r53v08g80000gn/T/ipykernel_57797/581128010.py:10: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def search_for_centos(musicxml_file: str, centos_list: list):
    """
    Search for given melodic centos in a MusicXML file and retrieve their occurrences.

    Parameters:
    - musicxml_file (str): Path to the MusicXML file.
    - centos_list (list): List of melodic centos represented as lists of pitch names or note objects.

    Returns:
    - list: List of dictionaries, each containing information about a found cento, its position, melodic contour, rhythmic values, and other details.
    """
    # Parse the MusicXML file
    score = converter.parse(musicxml_file)

    # List to store information about found centos
    found_centos_info = []

    # Iterate over parts in the score
    for part in score.parts:
        # Iterate over measures in the part
        for measure_number, measure in enumerate(part.getElementsByClass('Measure'), start=1):
            # Extract notes from the measure
            notes = measure.flat.getElementsByClass("Note")

            # Iterate over each cento in the centos_list
            for cento in centos_list:
                cento_length = len(cento)

                # Iterate over indices to search for the cento
                for i in range(len(notes) - cento_length + 1):
                    # Check if the current sequence of notes matches the cento
                    if [note.pitch.nameWithOctave for note in notes[i:i + cento_length]] == cento:
                        # Extract melodic and rhythmic information
                        melodic_contour = cento
                        rhythmic_values = [note.quarterLength for note in notes[i:i + cento_length]]

                        # Store information about the found cento
                        cento_info = {
                            'cento': cento,
                            'position': {
                                'measure': measure_number,
                                'start_index': i,
                                'end_index': i + cento_length - 1
                            },
                            'melodic_contour': melodic_contour,
                            'rhythmic_values': rhythmic_values,
                        }
                        found_centos_info.append(cento_info)

    return found_centos_info

# %%
sample_centos_list = [
    ['C4', 'D4', 'E4'],        # Ascending scale fragment
    ['G4', 'F4', 'E4'],        # Descending scale fragment
    ['A4', 'B4', 'A4'],        # Simple repeated pitch sequence
    ['F4', 'G4', 'A4', 'G4'],  # Simple ascending-descending pattern
    ['D4', 'E4', 'D4'],        # Repeated pitch with step
    # Add more centos as needed
]

# %%
found_centos_info=search_for_centos("/Users/oriolcolomefont/Documents/AMPLAB/Module 2/assignment/tests/ArabAndalusianSelectedScores-Annotations/7448d9c2-5261-4e70-bd98-6ed8416f908f.xml",sample_centos_list)
found_centos_info
# Out:
# [{'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 10, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 2.0]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 26, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [2.0, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 27, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 40, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 2.0]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 59, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 2.0]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 71, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 85, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 101, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 115, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 131, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 171, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 207, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 207, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 209, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 209, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 214, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 214, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 216, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 217, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 217, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 222, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 222, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 224, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 225, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 225, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 230, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 230, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 232, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 233, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 233, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 238, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 238, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 240, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 241, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 241, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 246, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 246, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 248, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 249, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 249, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 254, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 254, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 256, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 257, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 257, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 259, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 259, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 261, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 261, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 266, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 266, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 268, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 269, 'start_index': 10, 'end_index': 12},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 269, 'start_index': 7, 'end_index': 10},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 275, 'start_index': 7, 'end_index': 9},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 275, 'start_index': 4, 'end_index': 7},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [2.0, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 279, 'start_index': 7, 'end_index': 9},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 279, 'start_index': 4, 'end_index': 7},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [2.0, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 286, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 286, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 288, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 288, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 289, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 289, 'start_index': 7, 'end_index': 9},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 293, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 297, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 301, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 305, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 310, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 310, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 312, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 312, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 313, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 313, 'start_index': 7, 'end_index': 9},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 318, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 318, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 320, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 320, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 321, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 321, 'start_index': 7, 'end_index': 9},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 326, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 326, 'start_index': 8, 'end_index': 10},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 328, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure':
 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1115, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 1115, 'start_index': 1, 'end_index': 4},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1119, 'start_index': 2, 'end_index': 4},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1120, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 1120, 'start_index': 1, 'end_index': 4},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1125, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1126, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1126, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1129, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.0]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1130, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 1130, 'start_index': 1, 'end_index': 4},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1131, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1134, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1141, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1142, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1142, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1145, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.0]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1146, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 1146, 'start_index': 1, 'end_index': 4},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1147, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1150, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1157, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1158, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1158, 'start_index': 5, 'end_index': 7},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.25, 0.25]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1161, 'start_index': 0, 'end_index': 2},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 1.0]},
#  {'cento': ['G4', 'F4', 'E4'],
#   'position': {'measure': 1162, 'start_index': 4, 'end_index': 6},
#   'melodic_contour': ['G4', 'F4', 'E4'],
#   'rhythmic_values': [0.25, 0.25, 0.25]},
#  {'cento': ['F4', 'G4', 'A4', 'G4'],
#   'position': {'measure': 1162, 'start_index': 1, 'end_index': 4},
#   'melodic_contour': ['F4', 'G4', 'A4', 'G4'],
#   'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1163, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]},
#  {'cento': ['C4', 'D4', 'E4'],
#   'position': {'measure': 1166, 'start_index': 1, 'end_index': 3},
#   'melodic_contour': ['C4', 'D4', 'E4'],
#   'rhythmic_values': [0.5, 0.5, 0.5]}]

# %%
def analyze_repetition(found_centos_info: list):
    """
    Analyze repetition information for each found cento in the provided list.

    Parameters:
    - found_centos_info (list): List of dictionaries, each containing information about a found cento.

    Returns:
    - dict: Dictionary containing repetition information for each cento.
    """
    repetition_info = {}

    for cento_info in found_centos_info:
        cento_key = (tuple(cento_info['melodic_contour']), tuple(cento_info['rhythmic_values']))

        # Check if the cento is already in the dictionary
        if cento_key in repetition_info:
            repetition_info[cento_key]['occurrences'].append(cento_info['position'])
        else:
            repetition_info[cento_key] = {
                'occurrences': [cento_info['position']],
                'melodic_contour': cento_info['melodic_contour'],
                'rhythmic_values': cento_info['rhythmic_values'],
                # Add any other relevant details here
            }

    return repetition_info

# %%
repetition_info = analyze_repetition(found_centos_info)
repetition_info
# Out:
# {(('G4', 'F4', 'E4'),
#   (0.5,
#    0.5,
#    2.0)): {'occurrences': [{'measure': 10,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 40, 'start_index': 0, 'end_index': 2}, {'measure': 59,
#     'start_index': 0,
#     'end_index': 2}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.5, 0.5, 2.0]},
#  (('G4', 'F4', 'E4'),
#   (2.0,
#    0.5,
#    0.5)): {'occurrences': [{'measure': 26,
#     'start_index': 0,
#     'end_index': 2}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [2.0, 0.5, 0.5]},
#  (('G4', 'F4', 'E4'),
#   (0.5,
#    0.5,
#    0.5)): {'occurrences': [{'measure': 27,
#     'start_index': 5,
#     'end_index': 7}, {'measure': 286, 'start_index': 8, 'end_index': 10}, {'measure': 288,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 289,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 310, 'start_index': 8, 'end_index': 10}, {'measure': 312,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 313,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 318, 'start_index': 8, 'end_index': 10}, {'measure': 320,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 321,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 326, 'start_index': 8, 'end_index': 10}, {'measure': 328,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 329,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 334, 'start_index': 8, 'end_index': 10}, {'measure': 336,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 337,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 342, 'start_index': 8, 'end_index': 10}, {'measure': 344,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 345,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 362, 'start_index': 8, 'end_index': 10}, {'measure': 364,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 365,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 386, 'start_index': 8, 'end_index': 10}, {'measure': 388,
#     'start_index': 8,
#     'end_index': 10}, {'measure': 389,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 429, 'start_index': 2, 'end_index': 4}, {'measure': 432,
#     'start_index': 8,
#     'end_index': 10}, {'measure':

#     'start_index': 7,
#     'end_index': 10}, {'measure': 792,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 803, 'start_index': 7, 'end_index': 10}, {'measure': 805,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 808,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 815, 'start_index': 3, 'end_index': 6}, {'measure': 821,
#     'start_index': 3,
#     'end_index': 6}, {'measure': 827,
#     'start_index': 3,
#     'end_index': 6}, {'measure': 833, 'start_index': 3, 'end_index': 6}, {'measure': 839,
#     'start_index': 3,
#     'end_index': 6}, {'measure': 1063,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1068, 'start_index': 1, 'end_index': 4}, {'measure': 1071,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1076,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1079, 'start_index': 1, 'end_index': 4}, {'measure': 1084,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1087,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1092, 'start_index': 1, 'end_index': 4}, {'measure': 1095,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1100,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1112, 'start_index': 1, 'end_index': 4}, {'measure': 1115,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1120,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1130, 'start_index': 1, 'end_index': 4}, {'measure': 1146,
#     'start_index': 1,
#     'end_index': 4}, {'measure': 1162,
#     'start_index': 1,
#     'end_index': 4}], 'melodic_contour': ['F4',
#    'G4',
#    'A4',
#    'G4'], 'rhythmic_values': [0.25, 0.25, 0.25, 0.25]},
#  (('G4', 'F4', 'E4'),
#   (0.25,
#    0.25,
#    0.5)): {'occurrences': [{'measure': 275, 'start_index': 7, 'end_index': 9},
#    {'measure': 279, 'start_index': 7, 'end_index': 9},
#    {'measure': 286, 'start_index': 2, 'end_index': 4},
#    {'measure': 288, 'start_index': 2, 'end_index': 4},
#    {'measure': 310, 'start_index': 2, 'end_index': 4},
#    {'measure': 312, 'start_index': 2, 'end_index': 4},
#    {'measure': 318, 'start_index': 2, 'end_index': 4},
#    {'measure': 320, 'start_index': 2, 'end_index': 4},
#    {'measure': 326, 'start_index': 2, 'end_index': 4},
#    {'measure': 328, 'start_index': 2, 'end_index': 4},
#    {'measure': 334, 'start_index': 2, 'end_index': 4},
#    {'measure': 336, 'start_index': 2, 'end_index': 4},
#    {'measure': 342, 'start_index': 2, 'end_index': 4},
#    {'measure': 344, 'start_index': 2, 'end_index': 4},
#    {'measure': 351, 'start_index': 7, 'end_index': 9},
#    {'measure': 355, 'start_index': 7, 'end_index': 9},
#    {'measure': 362, 'start_index': 2, 'end_index': 4},
#    {'measure': 364, 'start_index': 2, 'end_index': 4},
#    {'measure': 386, 'start_index': 2, 'end_index': 4},
#    {'measure': 388, 'start_index': 2, 'end_index': 4},
#    {'measure': 426, 'start_index': 7, 'end_index': 9},
#    {'measure': 433, 'start_index': 5, 'end_index': 7},
#    {'measure': 461, 'start_index': 5, 'end_index': 7},
#    {'measure': 489, 'start_index': 5, 'end_index': 7},
#    {'measure': 517, 'start_index': 5, 'end_index': 7},
#    {'measure': 545, 'start_index': 5, 'end_index': 7},
#    {'measure': 573, 'start_index': 5, 'end_index': 7},
#    {'measure': 613, 'start_index': 7, 'end_index': 9},
#    {'measure': 620, 'start_index': 5, 'end_index': 7},
#    {'measure': 727, 'start_index': 7, 'end_index': 9},
#    {'measure': 729,
#     'start_index': 7,
#     'end_index': 9}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.25, 0.25, 0.5]},
#  (('F4', 'G4', 'A4', 'G4'),
#   (2.0,
#    0.25,
#    0.25,
#    0.25)): {'occurrences': [{'measure': 275,
#     'start_index': 4,
#     'end_index': 7}, {'measure': 279,
#     'start_index': 4,
#     'end_index': 7}, {'measure': 351,
#     'start_index': 4,
#     'end_index': 7}, {'measure': 355,
#     'start_index': 4,
#     'end_index': 7}], 'melodic_contour': ['F4',
#    'G4',
#    'A4',
#    'G4'], 'rhythmic_values': [2.0, 0.25, 0.25, 0.25]},
#  (('G4', 'F4', 'E4'),
#   (0.5,
#    0.5,
#    1.5)): {'occurrences': [{'measure': 293, 'start_index': 5, 'end_index': 7},
#    {'measure': 297, 'start_index': 5, 'end_index': 7},
#    {'measure': 301, 'start_index': 5, 'end_index': 7},
#    {'measure': 305, 'start_index': 5, 'end_index': 7},
#    {'measure': 369, 'start_index': 5, 'end_index': 7},
#    {'measure': 373, 'start_index': 5, 'end_index': 7},
#    {'measure': 377, 'start_index': 5, 'end_index': 7},
#    {'measure': 381,
#     'start_index': 5,
#     'end_index': 7}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.5, 0.5, 1.5]},
#  (('D4', 'E4', 'D4'),
#   (0.25,
#    0.25,
#    0.25)): {'occurrences': [{'measure': 392,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 404,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 416,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 579,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 591,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 603,
#     'start_index': 3,
#     'end_index': 5}], 'melodic_contour': ['D4',
#    'E4',
#    'D4'], 'rhythmic_values': [0.25, 0.25, 0.25]},
#  (('G4', 'F4', 'E4'),
#   (0.5,
#    1.0,
#    1.0)): {'occurrences': [{'measure': 399,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 411,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 423,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 586,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 598,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 610,
#     'start_index': 1,
#     'end_index': 3}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.5, 1.0, 1.0]},
#  (('D4', 'E4', 'D4'),
#   (0.5,
#    0.5,
#    0.5)): {'occurrences': [{'measure': 400,
#     'start_index': 6,
#     'end_index': 8}, {'measure': 412,
#     'start_index': 6,
#     'end_index': 8}, {'measure': 424,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 430,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 437,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 451,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 458,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 465,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 479,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 486,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 493,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 507,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 514,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 521,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 535,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 542,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 549,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 563,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 570,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 577,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 587,
#     'start_index': 6,
#     'end_index': 8}, {'measure': 599,
#     'start_index': 6,
#     'end_index': 8}, {'measure': 611,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 617,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 624,
#     'start_index': 0,
#     'end_index': 2}], 'melodic_contour': ['D4',
#    'E4',
#    'D4'], 'rhythmic_values': [0.5, 0.5, 0.5]},
#  (('C4', 'D4', 'E4'),
#   (1.0,
#    0.5,
#    0.25)): {'occurrences': [{'measure': 402,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 414,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 589,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 601,
#     'start_index': 1,
#     'end_index': 3}], 'melodic_contour': ['C4',
#    'D4',
#    'E4'], 'rhythmic_values': [1.0, 0.5, 0.25]},
#  (('C4', 'D4', 'E4'),
#   (0.5,
#    0.5,
#    0.75)): {'occurrences': [{'measure': 426,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 613,
#     'start_index': 1,
#     'end_index': 3}], 'melodic_contour': ['C4',
#    'D4',
#    'E4'], 'rhythmic_values': [0.5, 0.5, 0.75]},
#  (('F4', 'G4', 'A4', 'G4'),
#   (0.5,
#    0.5,
#    1.0,
#    0.5)): {'occurrences': [{'measure': 428,
#     'start_index': 6,
#     'end_index': 9}, {'measure': 442,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 446,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 456,
#     'start_index': 6,
#     'end_index': 9}, {'measure': 470,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 474,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 484,
#     'start_index': 6,
#     'end_index': 9}, {'measure': 498,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 502,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 512,
#     'start_index': 6,
#     'end_index': 9}, {'measure': 526,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 530,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 540,
#     'start_index': 6,
#     'end_index': 9}, {'measure': 554,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 558,
#     'start_index': 7,
#     'end_index': 10}, {'measure': 568,
#     'start_index': 6,
#     'end_index': 9}, {'measure': 615,
#     'start_index': 6,
#     'end_index': 9}], 'melodic_contour': ['F4',
#    'G4',
#    'A4',
#    'G4'], 'rhythmic_values': [0.5, 0.5, 1.0, 0.5]},
#  (('C4', 'D4', 'E4'),
#   (0.5,
#    0.5,
#    0.25)): {'occurrences': [{'measure': 432, 'start_index': 4, 'end_index': 6},
#    {'measure': 460, 'start_index': 4, 'end_index': 6},
#    {'measure': 488, 'start_index': 4, 'end_index': 6},
#    {'measure': 516, 'start_index': 4, 'end_index': 6},
#    {'measure': 544, 'start_index': 4, 'end_index': 6},
#    {'measure': 572, 'start_index': 4, 'end_index': 6},
#    {'measure': 619, 'start_index': 4, 'end_index': 6},
#    {'measure': 1126, 'start_index': 1, 'end_index': 3},
#    {'measure': 1142, 'start_index': 1, 'end_index': 3},
#    {'measure': 1158,
#     'start_index': 1,
#     'end_index': 3}], 'melodic_contour': ['C4',
#    'D4',
#    'E4'], 'rhythmic_values': [0.5, 0.5, 0.25]},
#  (('G4', 'F4', 'E4'),
#   (0.5,
#    0.25,
#    0.25)): {'occurrences': [{'measure': 434,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 462,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 490,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 518,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 546,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 574,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 621,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 866,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 874,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 882,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 890,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 898,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 906,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 928,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1067,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1075,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1083,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1091,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1099,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1111,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1119,
#     'start_index': 2,
#     'end_index': 4}, {'measure': 1125,
#     'start_index': 4,
#     'end_index': 6}, {'measure': 1126,
#     'start_index': 5,
#     'end_index': 7}, {'measure': 1141,
#     'start_index': 4,
#     'end_index': 6}, {'measure': 1142,
#     'start_index': 5,
#     'end_index': 7}, {'measure': 1157,
#     'start_index': 4,
#     'end_index': 6}, {'measure': 1158,
#     'start_index': 5,
#     'end_index': 7}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.5, 0.25, 0.25]},
#  (('G4', 'F4', 'E4'),
#   (0.5,
#    0.5,
#    0.25)): {'occurrences': [{'measure': 436,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 450,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 464,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 478,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 492,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 506,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 520,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 534,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 548,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 562,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 576,
#     'start_index': 3,
#     'end_index': 5}, {'measure': 623,
#     'start_index': 3,
#     'end_index': 5}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.5, 0.5, 0.25]},
#  (('C4', 'D4', 'E4'),
#   (1.0,
#    1.0,
#    1.0)): {'occurrences': [{'measure': 812,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 816,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 818,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 822,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 824,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 828,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 830,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 834,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 836,
#     'start_index': 1,
#     'end_index': 3}, {'measure': 840,
#     'start_index': 1,
#     'end_index': 3}], 'melodic_contour': ['C4',
#    'D4',
#    'E4'], 'rhythmic_values': [1.0, 1.0, 1.0]},
#  (('G4', 'F4', 'E4'),
#   (0.25,
#    0.25,
#    1.0)): {'occurrences': [{'measure': 843,
#     'start_index': 7,
#     'end_index': 9}, {'measure': 845,
#     'start_index': 7,
#     'end_index': 9}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.25, 0.25, 1.0]},
#  (('G4', 'F4', 'E4'),
#   (1.0,
#    0.5,
#    0.5)): {'occurrences': [{'measure': 944,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 954,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 964,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 974,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 984,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 988,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 992,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 996,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1006,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1014,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1022,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1030,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1038,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1046,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1048,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1050,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1058,
#     'start_index': 0,
#     'end_index': 2}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [1.0, 0.5, 0.5]},
#  (('G4', 'F4', 'E4'),
#   (1.0,
#    1.0,
#    1.0)): {'occurrences': [{'measure': 1012,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1020,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1028,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1036,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1044,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1056,
#     'start_index': 0,
#     'end_index': 2}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [1.0, 1.0, 1.0]},
#  (('G4', 'F4', 'E4'),
#   (0.5,
#    0.5,
#    1.0)): {'occurrences': [{'measure': 1129,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1145,
#     'start_index': 0,
#     'end_index': 2}, {'measure': 1161,
#     'start_index': 0,
#     'end_index': 2}], 'melodic_contour': ['G4',
#    'F4',
#    'E4'], 'rhythmic_values': [0.5, 0.5, 1.0]}}

# %%
keys = repetition_info.keys()
keys
# Out:
# dict_keys([(('G4', 'F4', 'E4'), (0.5, 0.5, 2.0)), (('G4', 'F4', 'E4'), (2.0, 0.5, 0.5)), (('G4', 'F4', 'E4'), (0.5, 0.5, 0.5)), (('C4', 'D4', 'E4'), (0.5, 0.5, 0.5)), (('G4', 'F4', 'E4'), (0.25, 0.25, 0.25)), (('F4', 'G4', 'A4', 'G4'), (0.25, 0.25, 0.25, 0.25)), (('G4', 'F4', 'E4'), (0.25, 0.25, 0.5)), (('F4', 'G4', 'A4', 'G4'), (2.0, 0.25, 0.25, 0.25)), (('G4', 'F4', 'E4'), (0.5, 0.5, 1.5)), (('D4', 'E4', 'D4'), (0.25, 0.25, 0.25)), (('G4', 'F4', 'E4'), (0.5, 1.0, 1.0)), (('D4', 'E4', 'D4'), (0.5, 0.5, 0.5)), (('C4', 'D4', 'E4'), (1.0, 0.5, 0.25)), (('C4', 'D4', 'E4'), (0.5, 0.5, 0.75)), (('F4', 'G4', 'A4', 'G4'), (0.5, 0.5, 1.0, 0.5)), (('C4', 'D4', 'E4'), (0.5, 0.5, 0.25)), (('G4', 'F4', 'E4'), (0.5, 0.25, 0.25)), (('G4', 'F4', 'E4'), (0.5, 0.5, 0.25)), (('C4', 'D4', 'E4'), (1.0, 1.0, 1.0)), (('G4', 'F4', 'E4'), (0.25, 0.25, 1.0)), (('G4', 'F4', 'E4'), (1.0, 0.5, 0.5)), (('G4', 'F4', 'E4'), (1.0, 1.0, 1.0)), (('G4', 'F4', 'E4'), (0.5, 0.5, 1.0))])
